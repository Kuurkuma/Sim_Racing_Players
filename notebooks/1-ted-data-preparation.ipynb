# %% [markdown]
# # Sim-Racing Steam DB analysis
#
# Hypothesis: "Sim racing is getting more & more popular"
#
# *Analysis of the Steam database with 10 games tagged "Automobile Sim".*
#
# The data are .csv files coming from the SteamDB website, which fetch data directly from a SteamAPI.

# %% [markdown]
# ## Import libraries

# %%
import os
import pandas as pd
import numpy as np
import glob
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load & concatenate all data sets
# all .csv files have the same structure, same variables.

# %%
folder_path = '/Users/macbook/Dropbox/Mac/Documents/Pro/Data_Analyst/sim-racing-steam-db/data/raw'
dfs = {}

for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        game_name = os.path.splitext(file)[0]  # Extract game name from filename
        df = pd.read_csv(os.path.join(folder_path, file))
        df['game'] = game_name
        dfs[game_name] = df

# %%
merged_df = pd.concat(dfs.values(), ignore_index=True)

# %% [markdown]
# ### Checking the load & merge

# %%
merged_df.head(20)
# Out:
#                DateTime  Players  Average Players  Twitch Viewers  \
# 0   2013-10-01 00:00:00      8.0              NaN             NaN
# 1   2013-10-02 00:00:00      NaN              NaN             NaN
# 2   2013-10-03 00:00:00      NaN              NaN             NaN
# 3   2013-10-04 00:00:00      NaN              NaN             NaN
# 4   2013-10-05 00:00:00      NaN              NaN             NaN
# 5   2013-10-06 00:00:00      NaN              NaN             NaN
# 6   2013-10-07 00:00:00      NaN              NaN             NaN
# 7   2013-10-08 00:00:00      NaN              NaN             NaN
# 8   2013-10-09 00:00:00      NaN              NaN             NaN
# 9   2013-10-10 00:00:00      NaN              NaN             NaN
# 10  2013-10-11 00:00:00      NaN              NaN             NaN
# 11  2013-10-12 00:00:00      NaN              NaN             NaN
# 12  2013-10-13 00:00:00      NaN              NaN             NaN
# 13  2013-10-14 00:00:00      NaN              NaN             NaN
# 14  2013-10-15 00:00:00      NaN              NaN             NaN
# 15  2013-10-16 00:00:00      NaN              NaN             NaN
# 16  2013-10-17 00:00:00      NaN              NaN             NaN
# 17  2013-10-18 00:00:00      NaN              NaN             NaN
# 18  2013-10-19 00:00:00      NaN              NaN             NaN
# 19  2013-10-20 00:00:00      NaN              NaN             NaN
#
#              game DateTime;Players;Average Players;Twitch Viewers;game
# 0   Assetto_corsa                                                NaN
# 1   Assetto_corsa                                                NaN
# 2   Assetto_corsa                                                NaN
# 3   Assetto_corsa                                                NaN
# 4   Assetto_corsa                                                NaN
# 5   Assetto_corsa                                                NaN
# 6   Assetto_corsa                                                NaN
# 7   Assetto_corsa                                                NaN
# 8   Assetto_corsa                                                NaN
# 9   Assetto_corsa                                                NaN
# 10  Assetto_corsa                                                NaN
# 11  Assetto_corsa                                                NaN
# 12  Assetto_corsa                                                NaN
# 13  Assetto_corsa                                                NaN
# 14  Assetto_corsa                                                NaN
# 15  Assetto_corsa                                                NaN
# 16  Assetto_corsa                                                NaN
# 17  Assetto_corsa                                                NaN
# 18  Assetto_corsa                                                NaN
# 19  Assetto_corsa                                                NaN

# %%
merged_df.tail(20)
# Out:
#                   DateTime  Players  Average Players  Twitch Viewers  \
# 38645  2024-01-09 10:40:00    699.0              NaN            22.0
# 38646  2024-01-09 10:50:00    692.0              NaN            22.0
# 38647  2024-01-09 11:00:00    712.0            966.0            11.0
# 38648  2024-01-09 11:10:00    729.0              NaN            11.0
# 38649  2024-01-09 11:20:00    753.0              NaN            11.0
# 38650  2024-01-09 11:30:00    776.0              NaN            11.0
# 38651  2024-01-09 11:40:00    800.0              NaN            11.0
# 38652  2024-01-09 11:50:00    828.0              NaN            11.0
# 38653  2024-01-09 12:00:00    843.0            966.0            14.0
# 38654  2024-01-09 12:10:00    852.0              NaN            14.0
# 38655  2024-01-09 12:20:00    857.0              NaN            14.0
# 38656  2024-01-09 12:30:00    859.0              NaN            14.0
# 38657  2024-01-09 12:40:00    881.0              NaN            14.0
# 38658  2024-01-09 12:50:00    895.0              NaN            14.0
# 38659  2024-01-09 13:00:00    908.0            960.0            18.0
# 38660  2024-01-09 13:10:00    913.0              NaN            18.0
# 38661  2024-01-09 13:20:00    923.0              NaN            18.0
# 38662  2024-01-09 13:30:00      NaN              NaN            18.0
# 38663  2024-01-09 13:40:00      NaN              NaN            18.0
# 38664  2024-01-09 13:50:00      NaN              NaN            18.0
#
#                   game DateTime;Players;Average Players;Twitch Viewers;game
# 38645  DiRT_rally_2.0_                                                NaN
# 38646  DiRT_rally_2.0_                                                NaN
# 38647  DiRT_rally_2.0_                                                NaN
# 38648  DiRT_rally_2.0_                                                NaN
# 38649  DiRT_rally_2.0_                                                NaN
# 38650  DiRT_rally_2.0_                                                NaN
# 38651  DiRT_rally_2.0_                                                NaN
# 38652  DiRT_rally_2.0_                                                NaN
# 38653  DiRT_rally_2.0_                                                NaN
# 38654  DiRT_rally_2.0_                                                NaN
# 38655  DiRT_rally_2.0_                                                NaN
# 38656  DiRT_rally_2.0_                                                NaN
# 38657  DiRT_rally_2.0_                                                NaN
# 38658  DiRT_rally_2.0_                                                NaN
# 38659  DiRT_rally_2.0_                                                NaN
# 38660  DiRT_rally_2.0_                                                NaN
# 38661  DiRT_rally_2.0_                                                NaN
# 38662  DiRT_rally_2.0_                                                NaN
# 38663  DiRT_rally_2.0_                                                NaN
# 38664  DiRT_rally_2.0_                                                NaN

# %% [markdown]
# we see that in 2013, we had one records of player per day. IN our most recent records, it was done every 10 mins.

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38665 entries, 0 to 38664
# Data columns (total 6 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   DateTime                                              36175 non-null  object
#  1   Players                                               33790 non-null  float64
#  2   Average Players                                       10587 non-null  float64
#  3   Twitch Viewers                                        32387 non-null  float64
#  4   game                                                  38665 non-null  object
#  5   DateTime;Players;Average Players;Twitch Viewers;game  2490 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# we need to change the data type of datetime. Also, our function add a column we need to drop.

# %%
round(merged_df.describe())
# Out:
#        Players  Average Players  Twitch Viewers
# count  33790.0          10587.0         32387.0
# mean    9065.0           8455.0          1165.0
# std    11098.0           8626.0          3614.0
# min        1.0            265.0             0.0
# 25%     1609.0           2040.0            44.0
# 50%     4158.0           6321.0           236.0
# 75%    12690.0          11906.0           894.0
# max    81096.0          44392.0        127965.0

# %% [markdown]
# ## Data preparation & cleaning

# %% [markdown]
# Let's drop the extra column and rename the column headers

# %%
print(merged_df.columns)
# Out:
# Index(['DateTime', 'Players', 'Average Players', 'Twitch Viewers', 'game',
#        'DateTime;Players;Average Players;Twitch Viewers;game'],
#       dtype='object')

# %%
# drop extra column
merged_df.drop(columns=['DateTime;Players;Average Players;Twitch Viewers;game'], inplace=True)

# %%
print(merged_df.columns)
# Out:
# Index(['DateTime', 'Players', 'Average Players', 'Twitch Viewers', 'game'], dtype='object')

# %%
# rename column headers
merged_df.columns = ['datetime', 'players', 'average_players', 'twitch_viewers', 'game']

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38665 entries, 0 to 38664
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         36175 non-null  object
#  1   players          33790 non-null  float64
#  2   average_players  10587 non-null  float64
#  3   twitch_viewers   32387 non-null  float64
#  4   game             38665 non-null  object
# dtypes: float64(3), object(2)
# memory usage: 1.5+ MB

# %%
merged_df['datetime'] = merged_df['datetime'].astype('datetime64[s]')
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38665 entries, 0 to 38664
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         36175 non-null  datetime64[s]
#  1   players          33790 non-null  float64
#  2   average_players  10587 non-null  float64
#  3   twitch_viewers   32387 non-null  float64
#  4   game             38665 non-null  object
# dtypes: datetime64[s](1), float64(3), object(1)
# memory usage: 1.5+ MB

# %%
# create an alternative dataframe to test functions
df_test = merged_df

# %%
#check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# datetime

# %%
merged_df.tail()
# Out:
#                  datetime  players  average_players  twitch_viewers  \
# 38660 2024-01-09 13:10:00    913.0              NaN            18.0
# 38661 2024-01-09 13:20:00    923.0              NaN            18.0
# 38662 2024-01-09 13:30:00      NaN              NaN            18.0
# 38663 2024-01-09 13:40:00      NaN              NaN            18.0
# 38664 2024-01-09 13:50:00      NaN              NaN            18.0
#
#                   game
# 38660  DiRT_rally_2.0_
# 38661  DiRT_rally_2.0_
# 38662  DiRT_rally_2.0_
# 38663  DiRT_rally_2.0_
# 38664  DiRT_rally_2.0_

# %%
# Checking the Null values
print(merged_df.isnull().sum())
# Out:
# datetime            2490
# players             4875
# average_players    28078
# twitch_viewers      6278
# game                   0
# dtype: int64

# %%
null_dates = merged_df[merged_df['datetime'].isnull() == True]
null_dates
# Out:
#       datetime  players  average_players  twitch_viewers            game
# 14875      NaT      NaN              NaN             NaN  American_truck
# 14876      NaT      NaN              NaN             NaN  American_truck
# 14877      NaT      NaN              NaN             NaN  American_truck
# 14878      NaT      NaN              NaN             NaN  American_truck
# 14879      NaT      NaN              NaN             NaN  American_truck
# ...        ...      ...              ...             ...             ...
# 17360      NaT      NaN              NaN             NaN  American_truck
# 17361      NaT      NaN              NaN             NaN  American_truck
# 17362      NaT      NaN              NaN             NaN  American_truck
# 17363      NaT      NaN              NaN             NaN  American_truck
# 17364      NaT      NaN              NaN             NaN  American_truck
#
# [2490 rows x 5 columns]

# %% [markdown]
# We need to re-import the data set of the game American truck

# %%
game = merged_df['game'].unique()
game
# Out:
# array(['Assetto_corsa', 'Forza Horizon 5 Steam Charts',
#        'Forza Horizon 4 Steam Charts', 'Assetto_corsa_competizione',
#        'American_truck', 'BeamNG', 'Euro_truck_2',
#        'Automobilista 2 Steam Charts', 'CarX_drift_racing_online',
#        'DiRT_rally_2.0_'], dtype=object)

# %%
merged_df[merged_df['game']== 'American_truck'].isna().count()
# Out:
# datetime           2490
# players            2490
# average_players    2490
# twitch_viewers     2490
# game               2490
# dtype: int64

# %%
import plotly.express as px

fig = px.histogram(merged_df, x='datetime')
fig.show()

# %% [markdown]
# ## Exploratary analysis & visualisation

# %%
# Generate a range of dates between 2020-01-01 and 2023-12-31 (inclusive)
#date_range = pd.DateRange('2020-01-01', periods=365, freq='D')

# Select only those rows that have a date within the range
df_filtered = merged_df[(merged_df['datetime'] >= 2020-1-1) & (merged_df['datetime'] <= 2020-12-31)]
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:935, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     934 try:
# --> 935     other = self._validate_comparison_value(other)
#     936 except InvalidComparison:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:571, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     570 elif not is_list_like(other):
# --> 571     raise InvalidComparison(other)
#     573 elif len(other) != len(self):
#
# InvalidComparison: 2018
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       1 # Generate a range of dates between 2020-01-01 and 2023-12-31 (inclusive)
#       2 #date_range = pd.DateRange('2020-01-01', periods=365, freq='D')
#       3
#       4 # Select only those rows that have a date within the range
# ----> 5 df_filtered = merged_df[(merged_df['datetime'] >= 2020-1-1) & (merged_df['datetime'] <= 2020-12-31)]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:279, in comparison_op(left, right, op)
#     270         raise ValueError(
#     271             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     272         )
#     274 if should_extension_dispatch(lvalues, rvalues) or (
#     275     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     276     and not is_object_dtype(lvalues.dtype)
#     277 ):
#     278     # Call the method on lvalues
# --> 279     res_values = op(lvalues, rvalues)
#     281 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     282     # numpy does not like comparisons vs None
#     283     if op is operator.ne:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/datetimelike.py:937, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     935     other = self._validate_comparison_value(other)
#     936 except InvalidComparison:
# --> 937     return invalid_comparison(self, other, op)
#     939 dtype = getattr(other, "dtype", None)
#     940 if is_object_dtype(dtype):
#     941     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     942     #  comparison otherwise it would fail to raise when
#     943     #  comparing tz-aware and tz-naive
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/invalid.py:36, in invalid_comparison(left, right, op)
#      34 else:
#      35     typ = type(right).__name__
# ---> 36     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[s] and int

# %%
import plotly.express as px

fig = px.histogram(df_american, x='Players')
fig.show()

# %%
import plotly.express as px

fig = px.histogram(df_american, x='Twitch Viewers')
fig.show()

# %%
boxplot = px.box(df_american,x='Players')
boxplot.show()

# %% [markdown]
# ## Ask & Answer questions

# %% [markdown]
# ## Summary & conclusion
